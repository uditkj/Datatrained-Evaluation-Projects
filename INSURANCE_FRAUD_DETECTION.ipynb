# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("insurance_dataset.csv")
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0      250/500               1000                1406.91               0
# 1      250/500               2000                1197.22         5000000
# 2      100/300               2000                1413.14         5000000
# 3      250/500               2000                1415.74         6000000
# 4     500/1000               1000                1583.91         6000000
# ..         ...                ...                    ...             ...
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0         466132  ...                     YES              71610         6510
# 1         468176  ...                       ?               5070          780
# 2         430632  ...                      NO              34650         7700
# 3         608117  ...                      NO              63400         6340
# 4         610706  ...                      NO               6500         1300
# ..           ...  ...                     ...                ...          ...
# 995       431289  ...                       ?              87200        17440
# 996       608177  ...                       ?             108480        18080
# 997       442797  ...                     YES              67500         7500
# 998       441714  ...                     YES              46980         5220
# 999       612260  ...                       ?               5060          460
#
#     property_claim vehicle_claim   auto_make  auto_model auto_year  \
# 0            13020         52080        Saab         92x      2004
# 1              780          3510    Mercedes        E400      2007
# 2             3850         23100       Dodge         RAM      2007
# 3             6340         50720   Chevrolet       Tahoe      2014
# 4              650          4550      Accura         RSX      2009
# ..             ...           ...         ...         ...       ...
# 995           8720         61040       Honda      Accord      2006
# 996          18080         72320  Volkswagen      Passat      2015
# 997           7500         52500      Suburu     Impreza      1996
# 998           5220         36540        Audi          A5      1998
# 999            920          3680    Mercedes        E400      2007
#
#     fraud_reported _c39
# 0                Y  NaN
# 1                Y  NaN
# 2                N  NaN
# 3                Y  NaN
# 4                N  NaN
# ..             ...  ...
# 995              N  NaN
# 996              N  NaN
# 997              N  NaN
# 998              N  NaN
# 999              N  NaN
#
# [1000 rows x 40 columns]

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# incident_location               object
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# property_damage                 object
# bodily_injuries                  int64
# witnesses                        int64
# police_report_available         object
# total_claim_amount               int64
# injury_claim                     int64
# property_claim                   int64
# vehicle_claim                    int64
# auto_make                       object
# auto_model                      object
# auto_year                        int64
# fraud_reported                  object
# _c39                           float64
# dtype: object

# %% [markdown]
# # (EDA) Exploratory Data Analysis

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# only one column HAS NULL VALUE AND THAT TOO ALL NULL
#
# SO DROPPING IT

# %%
df.drop('_c39',axis=1,inplace=True)
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# 0       466132  ...         2                     YES              71610
# 1       468176  ...         0                       ?               5070
# 2       430632  ...         3                      NO              34650
# 3       608117  ...         2                      NO              63400
# 4       610706  ...         1                      NO               6500
#
#   injury_claim property_claim  vehicle_claim  auto_make auto_model auto_year  \
# 0         6510          13020          52080       Saab        92x      2004
# 1          780            780           3510   Mercedes       E400      2007
# 2         7700           3850          23100      Dodge        RAM      2007
# 3         6340           6340          50720  Chevrolet      Tahoe      2014
# 4         1300            650           4550     Accura        RSX      2009
#
#   fraud_reported
# 0              Y
# 1              Y
# 2              N
# 3              Y
# 4              N
#
# [5 rows x 39 columns]

# %% [markdown]
# SO NOW NO NULL VALUES OR MISSING VALUES PRESENT CAN MOVE FORWARD

# %%
df['policy_bind_date'].value_counts()
# Out:
# 28-04-1992    3
# 05-08-1992    3
# 01-01-2006    3
# 07-07-1996    2
# 07-11-1997    2
#              ..
# 06-03-2004    1
# 03-11-1990    1
# 21-10-2005    1
# 15-03-2007    1
# 30-06-2000    1
# Name: policy_bind_date, Length: 951, dtype: int64

# %%
df['incident_date'].unique()
# Out:
# array(['25-01-2015', '21-01-2015', '22-02-2015', '10-01-2015',
#        '17-02-2015', '02-01-2015', '13-01-2015', '27-02-2015',
#        '30-01-2015', '05-01-2015', '06-01-2015', '15-02-2015',
#        '22-01-2015', '08-01-2015', '15-01-2015', '29-01-2015',
#        '19-01-2015', '01-01-2015', '10-02-2015', '11-01-2015',
#        '24-02-2015', '09-01-2015', '28-01-2015', '07-01-2015',
#        '18-01-2015', '28-02-2015', '12-02-2015', '24-01-2015',
#        '03-01-2015', '16-01-2015', '14-02-2015', '21-02-2015',
#        '18-02-2015', '26-02-2015', '17-01-2015', '27-01-2015',
#        '11-02-2015', '12-01-2015', '06-02-2015', '20-01-2015',
#        '02-02-2015', '20-02-2015', '08-02-2015', '23-02-2015',
#        '01-03-2015', '14-01-2015', '19-02-2015', '09-02-2015',
#        '26-01-2015', '23-01-2015', '31-01-2015', '03-02-2015',
#        '01-02-2015', '05-02-2015', '25-02-2015', '16-02-2015',
#        '13-02-2015', '04-02-2015', '07-02-2015', '04-01-2015'],
#       dtype=object)

# %% [markdown]
# hence all the report are of yeaar 2015 and also of month 1,2,3 we can drop incident date.

# %%
df['Policy_Day']=pd.to_datetime(df.policy_bind_date,format="%d-%m-%Y").dt.day
df['Policy_Month']=pd.to_datetime(df.policy_bind_date,format="%d-%m-%Y").dt.month
df['Policy_Year']=pd.to_datetime(df.policy_bind_date,format="%d-%m-%Y").dt.year

df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... injury_claim property_claim vehicle_claim  auto_make  \
# 0       466132  ...         6510          13020         52080       Saab
# 1       468176  ...          780            780          3510   Mercedes
# 2       430632  ...         7700           3850         23100      Dodge
# 3       608117  ...         6340           6340         50720  Chevrolet
# 4       610706  ...         1300            650          4550     Accura
#
#   auto_model  auto_year  fraud_reported Policy_Day Policy_Month Policy_Year
# 0        92x       2004               Y         17           10        2014
# 1       E400       2007               Y         27            6        2006
# 2        RAM       2007               N          6            9        2000
# 3      Tahoe       2014               Y         25            5        1990
# 4        RSX       2009               N          6            6        2014
#
# [5 rows x 42 columns]

# %% [markdown]
# can drop policy bind date and incident date.

# %%
# dropping policy_bind_date and incident_date as it is now seperated 
df.drop('incident_date',axis=1,inplace=True)
df.drop('policy_bind_date',axis=1,inplace=True)
df.head()
# Out:
#    months_as_customer  age  policy_number policy_state policy_csl  \
# 0                 328   48         521585           OH    250/500
# 1                 228   42         342868           IN    250/500
# 2                 134   29         687698           OH    100/300
# 3                 256   41         227811           IL    250/500
# 4                 228   44         367455           IL   500/1000
#
#    policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0               1000                1406.91               0       466132
# 1               2000                1197.22         5000000       468176
# 2               2000                1413.14         5000000       430632
# 3               2000                1415.74         6000000       608117
# 4               1000                1583.91         6000000       610706
#
#   insured_sex  ... injury_claim property_claim vehicle_claim  auto_make  \
# 0        MALE  ...         6510          13020         52080       Saab
# 1        MALE  ...          780            780          3510   Mercedes
# 2      FEMALE  ...         7700           3850         23100      Dodge
# 3      FEMALE  ...         6340           6340         50720  Chevrolet
# 4        MALE  ...         1300            650          4550     Accura
#
#    auto_model  auto_year fraud_reported Policy_Day Policy_Month Policy_Year
# 0         92x       2004              Y         17           10        2014
# 1        E400       2007              Y         27            6        2006
# 2         RAM       2007              N          6            9        2000
# 3       Tahoe       2014              Y         25            5        1990
# 4         RSX       2009              N          6            6        2014
#
# [5 rows x 40 columns]

# %%
df['policy_csl'].value_counts()
# Out:
# 250/500     351
# 100/300     349
# 500/1000    300
# Name: policy_csl, dtype: int64

# %%
df[["limit", "total"]]=df["policy_csl"].str.split("/", expand=True)
df["policy_csl_decimal"] = df["limit"].astype(float) / df["total"].astype(float)

df.head()
# Out:
#    months_as_customer  age  policy_number policy_state policy_csl  \
# 0                 328   48         521585           OH    250/500
# 1                 228   42         342868           IN    250/500
# 2                 134   29         687698           OH    100/300
# 3                 256   41         227811           IL    250/500
# 4                 228   44         367455           IL   500/1000
#
#    policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0               1000                1406.91               0       466132
# 1               2000                1197.22         5000000       468176
# 2               2000                1413.14         5000000       430632
# 3               2000                1415.74         6000000       608117
# 4               1000                1583.91         6000000       610706
#
#   insured_sex  ...  auto_make auto_model auto_year fraud_reported  Policy_Day  \
# 0        MALE  ...       Saab        92x      2004              Y          17
# 1        MALE  ...   Mercedes       E400      2007              Y          27
# 2      FEMALE  ...      Dodge        RAM      2007              N           6
# 3      FEMALE  ...  Chevrolet      Tahoe      2014              Y          25
# 4        MALE  ...     Accura        RSX      2009              N           6
#
#    Policy_Month Policy_Year limit total policy_csl_decimal
# 0            10        2014   250   500           0.500000
# 1             6        2006   250   500           0.500000
# 2             9        2000   100   300           0.333333
# 3             5        1990   250   500           0.500000
# 4             6        2014   500  1000           0.500000
#
# [5 rows x 43 columns]

# %%
df.drop('policy_csl',axis=1,inplace=True)
df.drop('limit',axis=1,inplace=True)
df.drop('total',axis=1,inplace=True)

df.head()
# Out:
#    months_as_customer  age  policy_number policy_state  policy_deductable  \
# 0                 328   48         521585           OH               1000
# 1                 228   42         342868           IN               2000
# 2                 134   29         687698           OH               2000
# 3                 256   41         227811           IL               2000
# 4                 228   44         367455           IL               1000
#
#    policy_annual_premium  umbrella_limit  insured_zip insured_sex  \
# 0                1406.91               0       466132        MALE
# 1                1197.22         5000000       468176        MALE
# 2                1413.14         5000000       430632      FEMALE
# 3                1415.74         6000000       608117      FEMALE
# 4                1583.91         6000000       610706        MALE
#
#   insured_education_level  ... property_claim vehicle_claim  auto_make  \
# 0                      MD  ...          13020         52080       Saab
# 1                      MD  ...            780          3510   Mercedes
# 2                     PhD  ...           3850         23100      Dodge
# 3                     PhD  ...           6340         50720  Chevrolet
# 4               Associate  ...            650          4550     Accura
#
#    auto_model  auto_year fraud_reported Policy_Day Policy_Month Policy_Year  \
# 0         92x       2004              Y         17           10        2014
# 1        E400       2007              Y         27            6        2006
# 2         RAM       2007              N          6            9        2000
# 3       Tahoe       2014              Y         25            5        1990
# 4         RSX       2009              N          6            6        2014
#
#   policy_csl_decimal
# 0           0.500000
# 1           0.500000
# 2           0.333333
# 3           0.500000
# 4           0.500000
#
# [5 rows x 40 columns]

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['umbrella_limit'],palette='Greens')
df['umbrella_limit'].value_counts()
# Out:
#  0           798
#  6000000      57
#  5000000      46
#  4000000      39
#  7000000      29
#  3000000      12
#  8000000       8
#  9000000       5
#  2000000       3
#  10000000      2
# -1000000       1
# Name: umbrella_limit, dtype: int64

# %% [markdown]
# umbrella_limit 0 has highest count,i.e. many didn't included in insurance
#
# umbrella_limit in minus would mean they might have claimed earlier.
#
# umbrella limit is high around 6000000.

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['fraud_reported'],palette='Greens_r')
df['fraud_reported'].value_counts()
# Out:
# N    753
# Y    247
# Name: fraud_reported, dtype: int64

# %% [markdown]
# yes fraud report are low compared to no

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df,x='insured_education_level',hue='fraud_reported',palette='Greys')
df['insured_education_level'].value_counts()
# Out:
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: insured_education_level, dtype: int64

# %% [markdown]
# Fraud cases are not dependednt on education level as all group are having almost same count of fraud case

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df,x='collision_type',hue='fraud_reported',palette='Greys_r')
df['collision_type'].value_counts()
# Out:
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                  178
# Name: collision_type, dtype: int64

# %% [markdown]
# rear collision are having maximum no. of fraud case
#
# ? i.e. not knowing the collision type are having less fraud case

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df,x='incident_severity',hue='fraud_reported',palette='OrRd')

df['incident_severity'].value_counts()
# Out:
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: incident_severity, dtype: int64

# %% [markdown]
# MAJOR DAMAGE ARE HAVING HIGH FRAUD CASE AS MIGHT BE CLAIMING INSURANCE AFTER A MAJOR DAMAGE
#
# TRIVIAL DAMAGE ARE HAVING LOW COUNT ON FRAUD CASE

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df,x='authorities_contacted',hue='fraud_reported',palette='OrRd_r')
df['authorities_contacted'].value_counts()
# Out:
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# None          91
# Name: authorities_contacted, dtype: int64

# %% [markdown]
# EVEN AFTER CALLING POLICE,FIRE AND OTHER AUTHORITIES THEY HAVE A FRAUD CASE MARKED.
#
# WELL MANY CONTACTED POLICE AFTER DAMAGE AND CLAIMED INSURANCE

# %%
df['capital-gains'].value_counts()
# Out:
# 0         508
# 46300       5
# 68500       4
# 51500       4
# 48900       3
#          ...
# 47700       1
# 94800       1
# 90700       1
# 100500      1
# 54800       1
# Name: capital-gains, Length: 338, dtype: int64

# %%
df['capital-loss'].value_counts()
# Out:
#  0        475
# -53700      5
# -50300      5
# -31700      5
# -49200      4
#          ...
# -32600      1
# -46800      1
# -50600      1
# -40800      1
# -43900      1
# Name: capital-loss, Length: 354, dtype: int64

# %%
df['insured_occupation'].value_counts()
# Out:
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# other-service        71
# priv-house-serv      71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: insured_occupation, dtype: int64

# %%
df['insured_hobbies'].value_counts()
# Out:
# reading           64
# exercise          57
# paintball         57
# bungie-jumping    56
# golf              55
# camping           55
# movies            55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# base-jumping      49
# skydiving         49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: insured_hobbies, dtype: int64

# %%
colors=sns.color_palette('PuRd_r')
labels=df['insured_relationship'].dropna().unique()

plt.figure(figsize=(18,10))

plt.subplot(1,2,1)
plt.title('Insured Relationship Percentage')
plt.pie(df['insured_relationship'].value_counts(), 
        labels=labels, 
        colors=colors, 
        autopct='%.2f%%')

plt.subplot(1,2,2)
plt.title('Insured Relationship Bar Chart')
sns.countplot(x="insured_relationship", data=df, palette=colors,hue='fraud_reported')

df.insured_relationship.value_counts(dropna=False)
# Out:
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: insured_relationship, dtype: int64

# %% [markdown]
# Issued Relationship is evenly distributed almost
#
# other relative are high in fraud case.

# %%
colors=sns.color_palette('Set1')
labels=df['incident_type'].dropna().unique()

plt.figure(figsize=(18,10))

plt.subplot(1,2,1)
plt.title('incident_type Percentage')
plt.pie(df['incident_type'].value_counts(), 
        labels=labels, 
        colors=colors, 
        autopct='%.2f%%')

plt.subplot(1,2,2)
plt.title('incident_type Bar Chart')
sns.countplot(x="incident_type", data=df, palette=colors,hue='fraud_reported')

df.incident_type.value_counts(dropna=False)
# Out:
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: incident_type, dtype: int64

# %% [markdown]
# Single Vehicle Collision are high upto 41.9% followed by vehicle theft.
#
# least with parked car.

# %%
colors=sns.color_palette('Set3')
labels=df['number_of_vehicles_involved'].dropna().unique()

plt.figure(figsize=(18,10))

plt.subplot(1,2,1)
plt.title('number_of_vehicles_involved Percentage')
plt.pie(df['number_of_vehicles_involved'].value_counts(), 
        labels=labels, 
        colors=colors, 
        autopct='%.2f%%')

plt.subplot(1,2,2)
plt.title('number_of_vehicles_involved Bar Chart')
sns.countplot(x="number_of_vehicles_involved", data=df, palette=colors,hue='fraud_reported')

df.number_of_vehicles_involved.value_counts(dropna=False)
# Out:
# 1    581
# 3    358
# 4     31
# 2     30
# Name: number_of_vehicles_involved, dtype: int64

# %% [markdown]
# 1 VEHICLE INVOLVED IN COLLISION ARE HAVING HIGH CASES FOLLOWED BY 3 VEHICLES.

# %%
colors=sns.color_palette('Spectral')
labels=df['property_damage'].dropna().unique()

plt.figure(figsize=(18,10))

plt.subplot(1,2,1)
plt.title('property_damage Percentage')
plt.pie(df['property_damage'].value_counts(), 
        labels=labels, 
        colors=colors, 
        autopct='%.2f%%')

plt.subplot(1,2,2)
plt.title('property_damage Bar Chart')
sns.countplot(x="property_damage", data=df, palette=colors,hue='fraud_reported')

df.property_damage.value_counts(dropna=False)
# Out:
# ?      360
# NO     338
# YES    302
# Name: property_damage, dtype: int64

# %% [markdown]
# PROPERTY DAMAGE ARE EVEN IN ALL CASES .
# DONT KNOW ABOUT PROPERTY DAMAGE ARE ALSO HAVING SAME PERCENTAGE, BUT HAVE HIGH FRAUD CASE COMPARED TO OTHER

# %%
colors=sns.color_palette('gist_stern')
labels=df['bodily_injuries'].dropna().unique()

plt.figure(figsize=(18,10))

plt.subplot(1,2,1)
plt.title('bodily_injuries Percentage')
plt.pie(df['bodily_injuries'].value_counts(), 
        labels=labels, 
        colors=colors, 
        autopct='%.2f%%')

plt.subplot(1,2,2)
plt.title('bodily_injuries Bar Chart')
sns.countplot(x="bodily_injuries", data=df, palette=colors,hue='fraud_reported')

df.bodily_injuries.value_counts(dropna=False)
# Out:
# 0    340
# 2    332
# 1    328
# Name: bodily_injuries, dtype: int64

# %% [markdown]
# BODY INJURED 0,1,2 ARE HAVING SAME PERCENTAGE, ALSO HAVING SAME AMOUNT OF YES AND NO FRAUD CASE.

# %%
colors=sns.color_palette('twilight')
labels=df['police_report_available'].dropna().unique()

plt.figure(figsize=(18,10))

plt.subplot(1,2,1)
plt.title('police_report_available Percentage')
plt.pie(df['police_report_available'].value_counts(), 
        labels=labels, 
        colors=colors, 
        autopct='%.2f%%')

plt.subplot(1,2,2)
plt.title('police_report_available Bar Chart')
sns.countplot(x="police_report_available", data=df, palette=colors,hue='fraud_reported')

df.police_report_available.value_counts(dropna=False)
# Out:
# NO     343
# ?      343
# YES    314
# Name: police_report_available, dtype: int64

# %% [markdown]
# POLICE REPORT ALSO HAVE EVEN PERCENTAGE OF COUNT
#
# POLICE REPORT IS NOT NECESSARY IN MINOR CASE OR NON ACCIDENTAL FOR CLAIMING

# %%
colors=sns.color_palette('mako_r')
labels=df['witnesses'].dropna().unique()

plt.figure(figsize=(18,10))

plt.subplot(1,2,1)
plt.title('witnesses Percentage')
plt.pie(df['witnesses'].value_counts(), 
        labels=labels, 
        colors=colors, 
        autopct='%.2f%%')




plt.subplot(1,2,2)
plt.title('witnesses Bar Chart')
sns.countplot(x="witnesses", data=df, palette=colors,hue='fraud_reported')


df.witnesses.value_counts(dropna=False)
# Out:
# 1    258
# 2    250
# 0    249
# 3    243
# Name: witnesses, dtype: int64

# %% [markdown]
# WITNESSES ARE HAVING EQUAL DISTRIBUTION AROUND 25% FOR ANY NO. OF PEOPLE
#
# WITNESSES WITH 2 ARE HAVING HIGH FRAUD CASES.

# %%
colors=sns.color_palette('gist_stern')
labels=df['policy_csl_decimal'].dropna().unique()

plt.figure(figsize=(18,10))

plt.subplot(1,2,1)
plt.title('policy_csl_decimal Percentage')
plt.pie(df['policy_csl_decimal'].value_counts(), 
        labels=labels, 
        colors=colors, 
        autopct='%.2f%%')

plt.subplot(1,2,2)
plt.title('policy_csl_decimal Bar Chart')
sns.countplot(x="policy_csl_decimal", data=df, palette=colors,hue='fraud_reported')

df.bodily_injuries.value_counts(dropna=False)
# Out:
# 0    340
# 2    332
# 1    328
# Name: bodily_injuries, dtype: int64

# %% [markdown]
# POLICY CSL LEADS TO CLAIM A PERSON CAN HAVE ON INSURANCE AND ALSO DEPENDS ON INSURANCE TYPE

# %%
plt.figure(figsize=(10,8))
df.policy_state.value_counts().plot.pie(explode=[0.05,0.05,0.05],autopct='%1.1f%%',shadow=True);
df['policy_state'].value_counts()
# Out:
# OH    352
# IL    338
# IN    310
# Name: policy_state, dtype: int64

# %% [markdown]
# OH HAS THE HIGHEST CLAIM FOLLOWED BY IL AND IN

# %%
plt.figure(figsize=(18,10))
plt.subplot(1,2,1)
sns.scatterplot(data=df,x='vehicle_claim',y='total_claim_amount')


plt.subplot(1,2,2)
sns.scatterplot(data=df,x='injury_claim',y='property_claim')
# Out:
# <AxesSubplot:xlabel='injury_claim', ylabel='property_claim'>

# %% [markdown]
# VEHICLE CLAIM IS DIRECTLY PROPOTIONAL TO TOTAL CLAIM AMOUNT.
#
# INJURY CLAIM IS ALSO DIRECTLY PROPOTIONAL TO PROPERTY CLAIM

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# min               433.330000   -1.000000e+06  430104.000000       0.000000
# 25%              1089.607500    0.000000e+00  448404.500000       0.000000
# 50%              1257.200000    0.000000e+00  466445.500000       0.000000
# 75%              1415.695000    0.000000e+00  603251.000000   51025.000000
# max              2047.590000    1.000000e+07  620962.000000  100500.000000
#
#         capital-loss  incident_hour_of_the_day  ...    witnesses  \
# count    1000.000000               1000.000000  ...  1000.000000
# mean   -26793.700000                 11.644000  ...     1.487000
# std     28104.096686                  6.951373  ...     1.111335
# min   -111100.000000                  0.000000  ...     0.000000
# 25%    -51500.000000                  6.000000  ...     1.000000
# 50%    -23250.000000                 12.000000  ...     1.000000
# 75%         0.000000                 17.000000  ...     2.000000
# max         0.000000                 23.000000  ...     3.000000
#
#        total_claim_amount  injury_claim  property_claim  vehicle_claim  \
# count          1000.00000   1000.000000     1000.000000    1000.000000
# mean          52761.94000   7433.420000     7399.570000   37928.950000
# std           26401.53319   4880.951853     4824.726179   18886.252893
# min             100.00000      0.000000        0.000000      70.000000
# 25%           41812.50000   4295.000000     4445.000000   30292.500000
# 50%           58055.00000   6775.000000     6750.000000   42100.000000
# 75%           70592.50000  11305.000000    10885.000000   50822.500000
# max          114920.00000  21450.000000    23670.000000   79560.000000
#
#          auto_year   Policy_Day  Policy_Month  Policy_Year  policy_csl_decimal
# count  1000.000000  1000.000000   1000.000000  1000.000000         1000.000000
# mean   2005.103000    15.448000      6.559000  2001.604000            0.441833
# std       6.015861     8.808001      3.499824     7.360391            0.079482
# min    1995.000000     1.000000      1.000000  1990.000000            0.333333
# 25%    2000.000000     8.000000      3.000000  1995.000000            0.333333
# 50%    2005.000000    16.000000      7.000000  2002.000000            0.500000
# 75%    2010.000000    23.000000     10.000000  2008.000000            0.500000
# max    2015.000000    31.000000     12.000000  2015.000000            0.500000
#
# [8 rows x 22 columns]

# %% [markdown]
# POLICY_ANNUAL_PREMIUM , Capital-gain ,Capital-loss,and many other columns are having skewness.
#
# deviation is also seen which means outliers may be present.

# %%
# label encoding target for relating columns
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df['fraud_reported'] = LE.fit_transform(df['fraud_reported'])

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.922098       0.057555
# age                                    0.922098  1.000000       0.059413
# policy_number                          0.057555  0.059413       1.000000
# policy_deductable                      0.026807  0.029188      -0.006738
# policy_annual_premium                  0.005018  0.014404       0.022566
# umbrella_limit                         0.015498  0.018126       0.008968
# insured_zip                            0.017895  0.025604       0.007083
# capital-gains                          0.006399 -0.007075       0.009802
# capital-loss                           0.020209  0.007368      -0.005669
# incident_hour_of_the_day               0.070639  0.087161       0.000113
# number_of_vehicles_involved            0.014736  0.022102       0.013432
# bodily_injuries                       -0.010162 -0.015679      -0.004558
# witnesses                              0.058383  0.052359      -0.012661
# total_claim_amount                     0.062108  0.069863      -0.018009
# injury_claim                           0.065329  0.075522      -0.008762
# property_claim                         0.034940  0.060898      -0.010678
# vehicle_claim                          0.061013  0.062588      -0.020184
# auto_year                             -0.000292  0.001354      -0.000183
# fraud_reported                         0.020544  0.012143      -0.029443
# Policy_Day                             0.054809  0.056776       0.045574
# Policy_Month                          -0.001559  0.008357      -0.003439
# Policy_Year                           -0.048276 -0.037444      -0.040099
# policy_csl_decimal                    -0.025164 -0.011516       0.069440
#
#                              policy_deductable  policy_annual_premium  \
# months_as_customer                    0.026807               0.005018
# age                                   0.029188               0.014404
# policy_number                        -0.006738               0.022566
# policy_deductable                     1.000000              -0.003245
# policy_annual_premium                -0.003245               1.000000
# umbrella_limit                        0.010870              -0.006247
# insured_zip                           0.004545               0.032354
# capital-gains                         0.035212              -0.013738
# capital-loss                         -0.023544               0.023547
# incident_hour_of_the_day              0.060935              -0.001578
# number_of_vehicles_involved           0.051214              -0.045991
# bodily_injuries                      -0.022765               0.026780
# witnesses                             0.066639               0.002332
# total_claim_amount                    0.022839               0.009094
# injury_claim                          0.039107              -0.017633
# property_claim                        0.064792              -0.011654
# vehicle_claim                         0.005269               0.020246
# auto_year                             0.026105              -0.049226
# fraud_reported                        0.014817              -0.014480
# Policy_Day                           -0.000265              -0.037933
# Policy_Month                         -0.025020              -0.002480
# Policy_Year                          -0.049598               0.001249
# policy_csl_decimal                    0.001592               0.029115
#
#                              umbrella_limit  insured_zip  capital-gains  \
# months_as_customer                 0.015498     0.017895       0.006399
# age                                0.018126     0.025604      -0.007075
# policy_number                      0.008968     0.007083       0.009802
# policy_deductable                  0.010870     0.004545       0.035212
# policy_annual_premium             -0.006247     0.032354      -0.013738
# umbrella_limit                     1.000000     0.019671      -0.047268
# insured_zip                        0.019671     1.000000       0.006303
# capital-gains                     -0.047268     0.006303       1.000000
# capital-loss                      -0.024056     0.049372      -0.046904
# incident_hour_of_the_day          -0.023257     0.008274      -0.016406
# number_of_vehicles_involved       -0.021270     0.027448       0.061643
# bodily_injuries                    0.022743     0.028695       0.055829
# witnesses                         -0.006738     0.019805      -0.017651
# total_claim_amount                -0.040344    -0.033873       0.015980
# injury_claim                      -0.045412    -0.017495       0.025934
# property_claim                    -0.023790    -0.006841      -0.000779
# vehicle_claim                     -0.038584    -0.041083       0.015836
# auto_year                          0.009893    -0.032736       0.031398
# fraud_reported                     0.058622     0.019368      -0.019173
# Policy_Day                        -0.023361    -0.044250      -0.004664
# Policy_Month                      -0.045871     0.025924       0.021193
# Policy_Year                        0.048008    -0.001100       0.041249
# policy_csl_decimal                 0.033119     0.010793       0.006824
#
#                              capital-loss  incident_hour_of_the_day  ...  \
# months_as_customer               0.020209                  0.070639  ...
# age                              0.007368                  0.087161  ...
# policy_number                   -0.005669                  0.000113  ...
# policy_deductable               -0.023544                  0.060935  ...
# policy_annual_premium            0.023547                 -0.001578  ...
# umbrella_limit                  -0.024056                 -0.023257  ...
# insured_zip                      0.049372                  0.008274  ...
# capital-gains                   -0.046904                 -0.016406  ...
# capital-loss                     1.000000                 -0.025054  ...
# incident_hour_of_the_day        -0.025054                  1.000000  ...
# number_of_vehicles_involved     -0.014895                  0.120794  ...
# bodily_injuries                 -0.024418                 -0.034563  ...
# witnesses                       -0.041330                  0.006527  ...
# total_claim_amount              -0.036060                  0.217702  ...
# injury_claim                    -0.046060                  0.165768  ...
# property_claim                  -0.022863                  0.179536  ...
# vehicle_claim                   -0.032665                  0.215626  ...
# auto_year                       -0.056615                  0.021368  ...
# fraud_reported                  -0.014863                  0.004316  ...
# Policy_Day                      -0.025983                 -0.013954  ...
# Policy_Month                    -0.028124                  0.010163  ...
# Policy_Year                     -0.026420                  0.035412  ...
# policy_csl_decimal              -0.034386                  0.000832  ...
#
#                              total_claim_amount  injury_claim  property_claim  \
# months_as_customer                     0.062108      0.065329        0.034940
# age                                    0.069863      0.075522        0.060898
# policy_number                         -0.018009     -0.008762       -0.010678
# policy_deductable                      0.022839      0.039107        0.064792
# policy_annual_premium                  0.009094     -0.017633       -0.011654
# umbrella_limit                        -0.040344     -0.045412       -0.023790
# insured_zip                           -0.033873     -0.017495       -0.006841
# capital-gains                          0.015980      0.025934       -0.000779
# capital-loss                          -0.036060     -0.046060       -0.022863
# incident_hour_of_the_day               0.217702      0.165768        0.179536
# number_of_vehicles_involved            0.274278      0.224650        0.219084
# bodily_injuries                        0.047093      0.047319        0.039749
# witnesses                             -0.011114     -0.024843        0.052640
# total_claim_amount                     1.000000      0.805025        0.810686
# injury_claim                           0.805025      1.000000        0.563866
# property_claim                         0.810686      0.563866        1.000000
# vehicle_claim                          0.982773      0.722878        0.732090
# auto_year                             -0.035781     -0.013718       -0.014508
# fraud_reported                         0.163651      0.090975        0.137835
# Policy_Day                             0.014859      0.024859        0.007739
# Policy_Month                           0.013929     -0.008774        0.023367
# Policy_Year                           -0.000146      0.002529       -0.000970
# policy_csl_decimal                    -0.069471     -0.084282       -0.055300
#
#                              vehicle_claim  auto_year  fraud_reported  \
# months_as_customer                0.061013  -0.000292        0.020544
# age                               0.062588   0.001354        0.012143
# policy_number                    -0.020184  -0.000183       -0.029443
# policy_deductable                 0.005269   0.026105        0.014817
# policy_annual_premium             0.020246  -0.049226       -0.014480
# umbrella_limit                   -0.038584   0.009893        0.058622
# insured_zip                      -0.041083  -0.032736        0.019368
# capital-gains                     0.015836   0.031398       -0.019173
# capital-loss                     -0.032665  -0.056615       -0.014863
# incident_hour_of_the_day          0.215626   0.021368        0.004316
# number_of_vehicles_involved       0.269393   0.034554        0.051839
# bodily_injuries                   0.043449  -0.020527        0.033877
# witnesses                        -0.022564   0.045791        0.049497
# total_claim_amount                0.982773  -0.035781        0.163651
# injury_claim                      0.722878  -0.013718        0.090975
# property_claim                    0.732090  -0.014508        0.137835
# vehicle_claim                     1.000000  -0.042768        0.170049
# auto_year                        -0.042768   1.000000        0.007928
# fraud_reported                    0.170049   0.007928        1.000000
# Policy_Day                        0.012370   0.036552        0.063040
# Policy_Month                      0.015770  -0.030265       -0.035180
# Policy_Year                      -0.000610   0.015164       -0.000059
# policy_csl_decimal               -0.061206  -0.018162       -0.018471
#
#                              Policy_Day  Policy_Month  Policy_Year  \
# months_as_customer             0.054809     -0.001559    -0.048276
# age                            0.056776      0.008357    -0.037444
# policy_number                  0.045574     -0.003439    -0.040099
# policy_deductable             -0.000265     -0.025020    -0.049598
# policy_annual_premium         -0.037933     -0.002480     0.001249
# umbrella_limit                -0.023361     -0.045871     0.048008
# insured_zip                   -0.044250      0.025924    -0.001100
# capital-gains                 -0.004664      0.021193     0.041249
# capital-loss                  -0.025983     -0.028124    -0.026420
# incident_hour_of_the_day      -0.013954      0.010163     0.035412
# number_of_vehicles_involved   -0.000655     -0.026949     0.026595
# bodily_injuries               -0.045648     -0.025294     0.029987
# witnesses                     -0.008506      0.018727     0.055907
# total_claim_amount             0.014859      0.013929    -0.000146
# injury_claim                   0.024859     -0.008774     0.002529
# property_claim                 0.007739      0.023367    -0.000970
# vehicle_claim                  0.012370      0.015770    -0.000610
# auto_year                      0.036552     -0.030265     0.015164
# fraud_reported                 0.063040     -0.035180    -0.000059
# Policy_Day                     1.000000      0.030867     0.007943
# Policy_Month                   0.030867      1.000000    -0.029324
# Policy_Year                    0.007943     -0.029324     1.000000
# policy_csl_decimal             0.017957     -0.007742    -0.016884
#
#                              policy_csl_decimal
# months_as_customer                    -0.025164
# age                                   -0.011516
# policy_number                          0.069440
# policy_deductable                      0.001592
# policy_annual_premium                  0.029115
# umbrella_limit                         0.033119
# insured_zip                            0.010793
# capital-gains                          0.006824
# capital-loss                          -0.034386
# incident_hour_of_the_day               0.000832
# number_of_vehicles_involved           -0.018930
# bodily_injuries                       -0.009705
# witnesses                              0.073590
# total_claim_amount                    -0.069471
# injury_claim                          -0.084282
# property_claim                        -0.055300
# vehicle_claim                         -0.061206
# auto_year                             -0.018162
# fraud_reported                        -0.018471
# Policy_Day                             0.017957
# Policy_Month                          -0.007742
# Policy_Year                           -0.016884
# policy_csl_decimal                     1.000000
#
# [23 rows x 23 columns]

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True,cmap='cividis',linecolor='black',linewidths=0.2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# VEHICLE CLAIM,PROPERTY CLAIM,INJURY CLAIM,TOTAL AMOUNT CLAIM ARE HIGHLY CORRELATED TO EACH OTHER
#
# ALL OTHER COLUMNS ARE HAVING NORMAL CORRELATION ALSO WITH TARGET FRAUD DETECTION.
#
# AGE AND MONTH AS CUSTOMER ARE ALSO HIGHLY CORRELATED.

# %% [markdown]
# # LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
obj=['policy_state','insured_sex', 'insured_education_level',
       'insured_occupation', 'insured_hobbies', 'insured_relationship',
        'incident_type', 'collision_type',
       'incident_severity', 'authorities_contacted', 'incident_state',
       'incident_city', 'incident_location', 'property_damage','police_report_available','auto_make',
       'auto_model']

for o in obj:
    df[o] = LE.fit_transform(df[o])

df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_state                     int32
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                      int32
# insured_education_level          int32
# insured_occupation               int32
# insured_hobbies                  int32
# insured_relationship             int32
# capital-gains                    int64
# capital-loss                     int64
# incident_type                    int32
# collision_type                   int32
# incident_severity                int32
# authorities_contacted            int32
# incident_state                   int32
# incident_city                    int32
# incident_location                int32
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# property_damage                  int32
# bodily_injuries                  int64
# witnesses                        int64
# police_report_available          int32
# total_claim_amount               int64
# injury_claim                     int64
# property_claim                   int64
# vehicle_claim                    int64
# auto_make                        int32
# auto_model                       int32
# auto_year                        int64
# fraud_reported                   int32
# Policy_Day                       int64
# Policy_Month                     int64
# Policy_Year                      int64
# policy_csl_decimal             float64
# dtype: object

# %% [markdown]
# # Checking outliers

# %%
sns.set(style="darkgrid")
df.plot(kind='box',subplots=True,layout=(10,4),figsize=(10,15))
plt.tight_layout()

# %% [markdown]
# age,property_claim,umbrella limit and policy annual premium are having some outliers
#
# hence removing it.

# %% [markdown]
# # Removing outliers by zscore

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.07813958, 0.99083647, 0.09595307, ..., 0.98368427, 1.68499231,
#         0.73218735],
#        [0.2089946 , 0.33407345, 0.79152739, ..., 0.15980224, 0.59754971,
#         0.73218735],
#        [0.60800168, 1.08891308, 0.55056594, ..., 0.69781264, 0.21803224,
#         1.36577067],
#        ...,
#        [0.64276748, 0.54161057, 1.44891961, ..., 1.30328875, 0.18975873,
#         0.73218735],
#        [2.20802805, 2.52328351, 0.04786687, ..., 1.2695559 , 1.27720133,
#         0.73218735],
#        [2.19064515, 2.3043625 , 0.03830297, ..., 1.2695559 , 0.76175354,
#         0.73218735]])

# %%
threshold=2.5
print(np.where(z>2.5))
# Out:
# (array([  6,  20,  31,  43,  48,  50,  59,  66,  67,  88, 106, 115, 119,
#        133, 154, 157, 161, 163, 183, 184, 185, 202, 203, 226, 229, 248,
#        255, 262, 263, 299, 301, 314, 349, 358, 366, 379, 394, 421, 430,
#        458, 474, 486, 500, 503, 519, 533, 538, 541, 544, 588, 591, 619,
#        628, 657, 658, 664, 674, 681, 687, 700, 708, 712, 745, 747, 763,
#        791, 794, 795, 796, 807, 813, 816, 835, 836, 848, 848, 875, 878,
#        922, 936, 947, 975, 998], dtype=int64), array([29,  1,  6,  5,  6,  6, 13,  6,  1,  6, 30,  6,  6,  5,  6,  6,  6,
#        30,  6,  6,  6,  6,  1,  6,  5,  5,  6,  6,  6, 30, 30,  6,  6, 29,
#         6,  5,  6, 30,  6,  6,  6,  5, 30,  6,  6, 13,  1,  6,  5,  1, 30,
#         6,  5,  6,  6,  6,  6,  5, 30,  6, 30,  1, 30,  5,  5,  6,  6,  6,
#         5, 14,  6, 13,  6, 29,  6, 30,  6,  5,  6,  6,  1,  6,  1],
#       dtype=int64))

# %%
df1=df[(z<2.5).all(axis=1)]
x=df1
x
# Out:
#      months_as_customer  age  policy_number  policy_state  policy_deductable  \
# 0                   328   48         521585             2               1000
# 1                   228   42         342868             1               2000
# 2                   134   29         687698             2               2000
# 3                   256   41         227811             0               2000
# 4                   228   44         367455             0               1000
# ..                  ...  ...            ...           ...                ...
# 994                 141   30         681486             1               1000
# 995                   3   38         941851             2               1000
# 996                 285   41         186934             0               1000
# 997                 130   34         918516             2                500
# 999                 456   60         556080             2               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# 0                  1406.91               0       466132            1
# 1                  1197.22         5000000       468176            1
# 2                  1413.14         5000000       430632            0
# 3                  1415.74         6000000       608117            0
# 4                  1583.91         6000000       610706            1
# ..                     ...             ...          ...          ...
# 994                1347.04               0       430665            1
# 995                1310.80               0       431289            0
# 996                1436.79               0       608177            0
# 997                1383.49         3000000       442797            0
# 999                 766.19               0       612260            0
#
#      insured_education_level  ...  property_claim  vehicle_claim  auto_make  \
# 0                          4  ...           13020          52080         10
# 1                          4  ...             780           3510          8
# 2                          6  ...            3850          23100          4
# 3                          6  ...            6340          50720          3
# 4                          0  ...             650           4550          0
# ..                       ...  ...             ...            ...        ...
# 994                        2  ...            1080           4860          6
# 995                        5  ...            8720          61040          6
# 996                        6  ...           18080          72320         13
# 997                        5  ...            7500          52500         11
# 999                        0  ...             920           3680          8
#
#      auto_model  auto_year  fraud_reported  Policy_Day  Policy_Month  \
# 0             1       2004               1          17            10
# 1            12       2007               1          27             6
# 2            30       2007               0           6             9
# 3            34       2014               1          25             5
# 4            31       2009               0           6             6
# ..          ...        ...             ...         ...           ...
# 994          10       1996               0          24             3
# 995           6       2006               0          16             7
# 996          28       2015               0           5             1
# 997          19       1996               0          17             2
# 999          12       2007               0          11            11
#
#      Policy_Year  policy_csl_decimal
# 0           2014            0.500000
# 1           2006            0.500000
# 2           2000            0.333333
# 3           1990            0.500000
# 4           2014            0.500000
# ..           ...                 ...
# 994         2007            0.500000
# 995         1991            0.500000
# 996         2014            0.333333
# 997         2003            0.500000
# 999         1996            0.500000
#
# [918 rows x 40 columns]

# %%
sns.set(style="darkgrid")
df1.plot(kind='box',subplots=True,layout=(10,4),figsize=(10,15))
plt.tight_layout()

# %% [markdown]
# only one column is having few outliers lets check loss percentage first before removing more outliers

# %% [markdown]
# # Percentage loss

# %%
loss_percent=(1000-918)/918*100
print(loss_percent,'%')
# Out:
# 8.932461873638346 %

# %% [markdown]
# HENCE THE LOSS IS AROUND 9% SO CANNOT GO FURTHER WITH REMOVING OUTLIERS.

# %% [markdown]
# Separating Dataset

# %%
#independent column
x=df1.drop(['fraud_reported'],axis=1)
#target
y=df1['fraud_reported']

# %%
x.shape
# Out:
# (918, 39)

# %%
y.shape
# Out:
# (918,)

# %% [markdown]
# Checking Skewness

# %%
df1.skew()
# Out:
# months_as_customer             0.334901
# age                            0.413943
# policy_number                  0.050378
# policy_state                  -0.042770
# policy_deductable              0.475376
# policy_annual_premium          0.007686
# umbrella_limit                 1.996170
# insured_zip                    0.854993
# insured_sex                    0.148800
# insured_education_level        0.014516
# insured_occupation            -0.051583
# insured_hobbies               -0.042028
# insured_relationship           0.084467
# capital-gains                  0.434335
# capital-loss                  -0.386617
# incident_type                  0.091501
# collision_type                -0.195544
# incident_severity              0.260319
# authorities_contacted         -0.127711
# incident_state                -0.156948
# incident_city                  0.054415
# incident_location              0.003133
# incident_hour_of_the_day      -0.042100
# number_of_vehicles_involved    0.505034
# property_damage                0.076077
# bodily_injuries               -0.010031
# witnesses                      0.035202
# police_report_available        0.017904
# total_claim_amount            -0.602488
# injury_claim                   0.227496
# property_claim                 0.255562
# vehicle_claim                 -0.617459
# auto_make                     -0.026298
# auto_model                    -0.068820
# auto_year                     -0.052760
# fraud_reported                 1.235891
# Policy_Day                     0.048756
# Policy_Month                  -0.014554
# Policy_Year                    0.059523
# policy_csl_decimal            -0.601516
# dtype: float64

# %%
plt.figure(figsize=(30,35),facecolor='white')
plotnumber=1
for column in df.columns:
    if plotnumber<=40:
        ax=plt.subplot(10,4,plotnumber)
        sns.distplot(df1[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %% [markdown]
# CAPITAL GAIN ,CAPITAL LOSS,PROPERTY CLAIM,INJURY CLAIM,UMBRELLA LIMIT ARE HAVING SKEWNESS

# %% [markdown]
# # Removing Skewness

# %%
from sklearn.preprocessing import power_transform
df1['capital-gains']=power_transform(x,method='yeo-johnson')
df1['capital-loss']=power_transform(x,method='yeo-johnson')
df1['property_claim']=power_transform(x,method='yeo-johnson')
df1['injury_claim']=power_transform(x,method='yeo-johnson')
df1['umbrella_limit']=power_transform(x,method='yeo-johnson')
df1
# Out:
#      months_as_customer  age  policy_number  policy_state  policy_deductable  \
# 0                   328   48         521585             2               1000
# 1                   228   42         342868             1               2000
# 2                   134   29         687698             2               2000
# 3                   256   41         227811             0               2000
# 4                   228   44         367455             0               1000
# ..                  ...  ...            ...           ...                ...
# 994                 141   30         681486             1               1000
# 995                   3   38         941851             2               1000
# 996                 285   41         186934             0               1000
# 997                 130   34         918516             2                500
# 999                 456   60         556080             2               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# 0                  1406.91        1.082744       466132            1
# 1                  1197.22        0.321028       468176            1
# 2                  1413.14       -0.506356       430632            0
# 3                  1415.74        0.543846       608117            0
# 4                  1583.91        0.321028       610706            1
# ..                     ...             ...          ...          ...
# 994                1347.04       -0.439225       430665            1
# 995                1310.80       -2.275091       431289            0
# 996                1436.79        0.766266       608177            0
# 997                1383.49       -0.545234       442797            0
# 999                 766.19        1.952482       612260            0
#
#      insured_education_level  ...  property_claim  vehicle_claim  auto_make  \
# 0                          4  ...        1.082744          52080         10
# 1                          4  ...        0.321028           3510          8
# 2                          6  ...       -0.506356          23100          4
# 3                          6  ...        0.543846          50720          3
# 4                          0  ...        0.321028           4550          0
# ..                       ...  ...             ...            ...        ...
# 994                        2  ...       -0.439225           4860          6
# 995                        5  ...       -2.275091          61040          6
# 996                        6  ...        0.766266          72320         13
# 997                        5  ...       -0.545234          52500         11
# 999                        0  ...        1.952482           3680          8
#
#      auto_model  auto_year  fraud_reported  Policy_Day  Policy_Month  \
# 0             1       2004               1          17            10
# 1            12       2007               1          27             6
# 2            30       2007               0           6             9
# 3            34       2014               1          25             5
# 4            31       2009               0           6             6
# ..          ...        ...             ...         ...           ...
# 994          10       1996               0          24             3
# 995           6       2006               0          16             7
# 996          28       2015               0           5             1
# 997          19       1996               0          17             2
# 999          12       2007               0          11            11
#
#      Policy_Year  policy_csl_decimal
# 0           2014            0.500000
# 1           2006            0.500000
# 2           2000            0.333333
# 3           1990            0.500000
# 4           2014            0.500000
# ..           ...                 ...
# 994         2007            0.500000
# 995         1991            0.500000
# 996         2014            0.333333
# 997         2003            0.500000
# 999         1996            0.500000
#
# [918 rows x 40 columns]

# %%
skeww=['capital-gains','capital-loss','property_claim','injury_claim','umbrella_limit']

for s in skeww:
    sns.distplot(df1[s])
    plt.show()

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#      months_as_customer       age  policy_number  policy_state  \
# 0              1.117350  1.043277      -0.084169      1.177156
# 1              0.231705  0.372286      -0.775975     -0.027559
# 2             -0.600801 -1.081528       0.558847      1.177156
# 3              0.479686  0.260454      -1.221356     -1.232274
# 4              0.231705  0.595949      -0.680800     -1.232274
# ..                  ...       ...            ...           ...
# 913           -0.538806 -0.969697       0.534801     -0.027559
# 914           -1.760995 -0.075042       1.542663      1.177156
# 915            0.736522  0.260454      -1.379589     -1.232274
# 916           -0.636227 -0.522369       1.452334      1.177156
# 917            2.250975  2.385259       0.049360      1.177156
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0            -0.225660               0.643496       -0.431249    -0.477731
# 1             1.411934              -0.257272        2.243660    -0.448998
# 2             1.411934               0.670259        2.243660    -0.976752
# 3             1.411934               0.681428        2.778642     1.518146
# 4            -0.225660               1.403838        2.778642     1.554540
# ..                 ...                    ...             ...          ...
# 913          -0.225660               0.386312       -0.431249    -0.976289
# 914          -0.225660               0.230635       -0.431249    -0.967517
# 915          -0.225660               0.771852       -0.431249     1.518990
# 916          -1.044457               0.542891        1.173696    -0.805750
# 917          -0.225660              -2.108853       -0.431249     1.576384
#
#      insured_sex  insured_education_level  ...  injury_claim  property_claim  \
# 0       1.077033                 0.528789  ...     -0.189382        1.241434
# 1       1.077033                 0.528789  ...     -1.377938       -1.400935
# 2      -0.928477                 1.548597  ...      0.057456       -0.738184
# 3      -0.928477                 1.548597  ...     -0.224645       -0.200644
# 4       1.077033                -1.510827  ...     -1.270076       -1.429000
# ..           ...                      ...  ...           ...             ...
# 913     1.077033                -0.491019  ...     -1.427721       -1.336171
# 914    -0.928477                 1.038693  ...      2.077794        0.313150
# 915    -0.928477                 1.548597  ...      2.210547        2.333785
# 916    -0.928477                 1.038693  ...      0.015971        0.049777
# 917    -0.928477                -1.510827  ...     -1.444315       -1.370712
#
#      vehicle_claim  auto_make  auto_model  auto_year  Policy_Day  \
# 0         0.761684   0.842643   -1.641305  -0.185672    0.178020
# 1        -1.826047   0.348364   -0.649865   0.317616    1.308967
# 2        -0.782323  -0.640193    0.972491   0.317616   -1.066023
# 3         0.689226  -0.887333    1.333014   1.491956    1.082777
# 4        -1.770638  -1.628751    1.062621   0.653142   -1.066023
# ..             ...        ...         ...        ...         ...
# 913      -1.754121  -0.145915   -0.830127  -1.527775    0.969683
# 914       1.239059  -0.145915   -1.190651   0.149854    0.064925
# 915       1.840039   1.584061    0.792229   1.659719   -1.179117
# 916       0.784061   1.089782   -0.018949  -1.527775    0.178020
# 917      -1.816990   0.348364   -0.649865   0.317616   -0.500549
#
#      Policy_Month  Policy_Year  policy_csl_decimal
# 0        0.981108     1.681098            0.743841
# 1       -0.159686     0.597166            0.743841
# 2        0.695909    -0.215783           -1.344373
# 3       -0.444885    -1.570697            0.743841
# 4       -0.159686     1.681098            0.743841
# ..            ...          ...                 ...
# 913     -1.015282     0.732657            0.743841
# 914      0.125512    -1.435206            0.743841
# 915     -1.585679     1.681098           -1.344373
# 916     -1.300481     0.190692            0.743841
# 917      1.266307    -0.757748            0.743841
#
# [918 rows x 39 columns]

# %% [markdown]
# # Checking VIF values to solve multicollinearity

# %%
x.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_state',
#        'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
#        'insured_zip', 'insured_sex', 'insured_education_level',
#        'insured_occupation', 'insured_hobbies', 'insured_relationship',
#        'capital-gains', 'capital-loss', 'incident_type', 'collision_type',
#        'incident_severity', 'authorities_contacted', 'incident_state',
#        'incident_city', 'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'Policy_Day', 'Policy_Month', 'Policy_Year',
#        'policy_csl_decimal'],
#       dtype='object')

# %%
# Finding varience inflation factor in each scaled column i.e, x.shape[1] (1/(1-R2))

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#     VIF values                     Features
# 0     6.878282           months_as_customer
# 1     6.935287                          age
# 2     1.037484                policy_number
# 3     1.039676                 policy_state
# 4     1.048954            policy_deductable
# 5     1.043699        policy_annual_premium
# 6     1.040931               umbrella_limit
# 7     1.038616                  insured_zip
# 8     1.029059                  insured_sex
# 9     1.048356      insured_education_level
# 10    1.027402           insured_occupation
# 11    1.046557              insured_hobbies
# 12    1.057058         insured_relationship
# 13    1.035516                capital-gains
# 14    1.048859                 capital-loss
# 15    5.262433                incident_type
# 16    1.707498               collision_type
# 17    1.204299            incident_severity
# 18    1.084066        authorities_contacted
# 19    1.046364               incident_state
# 20    1.034784                incident_city
# 21    1.046257            incident_location
# 22    1.111474     incident_hour_of_the_day
# 23    5.250899  number_of_vehicles_involved
# 24    1.043510              property_damage
# 25    1.033502              bodily_injuries
# 26    1.053099                    witnesses
# 27    1.032894      police_report_available
# 28         inf           total_claim_amount
# 29         inf                 injury_claim
# 30         inf               property_claim
# 31         inf                vehicle_claim
# 32    1.072471                    auto_make
# 33    1.073248                   auto_model
# 34    1.034630                    auto_year
# 35    1.030773                   Policy_Day
# 36    1.037748                 Policy_Month
# 37    1.033149                  Policy_Year
# 38    1.044418           policy_csl_decimal

# %% [markdown]
# AS TOTAL CLAIM,PROPERTY CLAIM,VEHICLE CLAIM,INJURY CLAIM ARE SHOWING INF ,SO DROPPING TOTAL CLAIM AND LETS SEE AGAIN THE RESULTS OF VIF

# %%
x.drop('total_claim_amount',axis=1,inplace=True)

# %%
# Finding varience inflation factor in each scaled column i.e, x.shape[1] (1/(1-R2))

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#     VIF values                     Features
# 0     6.878282           months_as_customer
# 1     6.935287                          age
# 2     1.037484                policy_number
# 3     1.039676                 policy_state
# 4     1.048954            policy_deductable
# 5     1.043699        policy_annual_premium
# 6     1.040931               umbrella_limit
# 7     1.038616                  insured_zip
# 8     1.029059                  insured_sex
# 9     1.048356      insured_education_level
# 10    1.027402           insured_occupation
# 11    1.046557              insured_hobbies
# 12    1.057058         insured_relationship
# 13    1.035516                capital-gains
# 14    1.048859                 capital-loss
# 15    5.262433                incident_type
# 16    1.707498               collision_type
# 17    1.204299            incident_severity
# 18    1.084066        authorities_contacted
# 19    1.046364               incident_state
# 20    1.034784                incident_city
# 21    1.046257            incident_location
# 22    1.111474     incident_hour_of_the_day
# 23    5.250899  number_of_vehicles_involved
# 24    1.043510              property_damage
# 25    1.033502              bodily_injuries
# 26    1.053099                    witnesses
# 27    1.032894      police_report_available
# 28    2.216553                 injury_claim
# 29    2.305509               property_claim
# 30    3.734553                vehicle_claim
# 31    1.072471                    auto_make
# 32    1.073248                   auto_model
# 33    1.034630                    auto_year
# 34    1.030773                   Policy_Day
# 35    1.037748                 Policy_Month
# 36    1.033149                  Policy_Year
# 37    1.044418           policy_csl_decimal

# %% [markdown]
# as we can see that their is not multicolinearity seen as VIF is not above 10 for any column,so we can move forward for model building.

# %% [markdown]
# # Splitting the DataFrame and Model selection

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=170)

# %% [markdown]
# # 1)LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report,confusion_matrix

lo=LogisticRegression()
lo.fit(x_train,y_train)
lo.score(x_train,y_train)
predlo=lo.predict(x_test)


print('Accuracy Score is''\n',accuracy_score(y_test,predlo))
print('Confusion Matrix''\n',confusion_matrix(y_test,predlo))
print(classification_report(y_test,predlo))
# Out:
# Accuracy Score is
#  0.7970297029702971
# Confusion Matrix
#  [[145  21]
#  [ 20  16]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88       166
#            1       0.43      0.44      0.44        36
#
#     accuracy                           0.80       202
#    macro avg       0.66      0.66      0.66       202
# weighted avg       0.80      0.80      0.80       202

# %% [markdown]
# Cross Validation

# %%
test_accuracy= accuracy_score(y_test,predlo)

from sklearn.model_selection import cross_val_score
for i in range(2,10):
    cv_score=cross_val_score(lo,x,y,cv=i)
    cv_mean=cv_score.mean()
    print(f"At cross fold {i} the Cross Val score is {cv_mean*100} and Accuracy score is {test_accuracy*100}")
# Out:
# At cross fold 2 the Cross Val score is 78.10457516339869 and Accuracy score is 79.70297029702971
# At cross fold 3 the Cross Val score is 76.47058823529412 and Accuracy score is 79.70297029702971
# At cross fold 4 the Cross Val score is 78.32257452059996 and Accuracy score is 79.70297029702971
# At cross fold 5 the Cross Val score is 78.21572820147303 and Accuracy score is 79.70297029702971
# At cross fold 6 the Cross Val score is 77.2331154684096 and Accuracy score is 79.70297029702971
# At cross fold 7 the Cross Val score is 77.88407521231949 and Accuracy score is 79.70297029702971
# At cross fold 8 the Cross Val score is 78.10545385202136 and Accuracy score is 79.70297029702971
# At cross fold 9 the Cross Val score is 77.99564270152506 and Accuracy score is 79.70297029702971

# %% [markdown]
# # 2) DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
pred_dt=dt.predict(x_test)
print('Accuracy score''\n',accuracy_score(y_test,pred_dt))
print('Confusion Matrix''\n',confusion_matrix(y_test,pred_dt))
print('Classification Report''\n',classification_report(y_test,pred_dt))
# Out:
# Accuracy score
#  0.8514851485148515
# Confusion Matrix
#  [[143  23]
#  [  7  29]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.95      0.86      0.91       166
#            1       0.56      0.81      0.66        36
#
#     accuracy                           0.85       202
#    macro avg       0.76      0.83      0.78       202
# weighted avg       0.88      0.85      0.86       202

# %% [markdown]
# Cross Validation

# %%
test_accuracy = accuracy_score(y_test,pred_dt)

from sklearn.model_selection import cross_val_score
for i in range(2,10):
    cv_score=cross_val_score(dt,x,y,cv=i)
    cv_mean=cv_score.mean()
    print(f"At cross fold {i} the Cross Val score is {cv_mean*100} and Accuracy score is {test_accuracy*100}")
# Out:
# At cross fold 2 the Cross Val score is 78.32244008714598 and Accuracy score is 85.14851485148515
# At cross fold 3 the Cross Val score is 79.3028322440087 and Accuracy score is 85.14851485148515
# At cross fold 4 the Cross Val score is 80.39396240744256 and Accuracy score is 85.14851485148515
# At cross fold 5 the Cross Val score is 80.07008790686623 and Accuracy score is 85.14851485148515
# At cross fold 6 the Cross Val score is 80.61002178649237 and Accuracy score is 85.14851485148515
# At cross fold 7 the Cross Val score is 79.62724298602161 and Accuracy score is 85.14851485148515
# At cross fold 8 the Cross Val score is 80.07437070938215 and Accuracy score is 85.14851485148515
# At cross fold 9 the Cross Val score is 79.73856209150327 and Accuracy score is 85.14851485148515

# %% [markdown]
# # 3) RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
pred_rfc=rfc.predict(x_test)
print('Accuracy score''\n',accuracy_score(y_test,pred_rfc))
print('Confusion Matrix''\n',confusion_matrix(y_test,pred_rfc))
print('Classification Report''\n',classification_report(y_test,pred_rfc))
# Out:
# Accuracy score
#  0.806930693069307
# Confusion Matrix
#  [[146  20]
#  [ 19  17]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88       166
#            1       0.46      0.47      0.47        36
#
#     accuracy                           0.81       202
#    macro avg       0.67      0.68      0.67       202
# weighted avg       0.81      0.81      0.81       202

# %% [markdown]
# Cross Validation

# %%
test_accuracy= accuracy_score(y_test,pred_rfc)

from sklearn.model_selection import cross_val_score
for i in range(2,10):
    cv_score=cross_val_score(rfc,x,y,cv=i,n_jobs=2)
    cv_mean=cv_score.mean()

# %% [markdown]
# # 4) SUPPORT VECTOR CLASSIFIER

# %%
from sklearn.svm import SVC

svc=SVC()
svc.fit(x_train,y_train)
pred_svc=svc.predict(x_test)
print('Accuracy score''\n',accuracy_score(y_test,pred_svc))
print('Confusion Matrix''\n',confusion_matrix(y_test,pred_svc))
print('Classification Report''\n',classification_report(y_test,pred_svc))
# Out:
# Accuracy score
#  0.8168316831683168
# Confusion Matrix
#  [[164   2]
#  [ 35   1]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.82      0.99      0.90       166
#            1       0.33      0.03      0.05        36
#
#     accuracy                           0.82       202
#    macro avg       0.58      0.51      0.47       202
# weighted avg       0.74      0.82      0.75       202

# %% [markdown]
# Cross Validation

# %%
test_accuracy= accuracy_score(y_test,pred_svc)

from sklearn.model_selection import cross_val_score
for i in range(2,10):
    cv_score=cross_val_score(svc,x,y,cv=i)
    cv_mean=cv_score.mean()
    print(f"At cross fold {i} the Cross Val score is {cv_mean*100} and Accuracy score is {test_accuracy*100}")
# Out:
# At cross fold 2 the Cross Val score is 75.92592592592592 and Accuracy score is 81.68316831683168
# At cross fold 3 the Cross Val score is 75.599128540305 and Accuracy score is 81.68316831683168
# At cross fold 4 the Cross Val score is 76.03474463641543 and Accuracy score is 81.68316831683168
# At cross fold 5 the Cross Val score is 75.81848420052269 and Accuracy score is 81.68316831683168
# At cross fold 6 the Cross Val score is 76.1437908496732 and Accuracy score is 81.68316831683168
# At cross fold 7 the Cross Val score is 76.25078483857111 and Accuracy score is 81.68316831683168
# At cross fold 8 the Cross Val score is 76.03546910755149 and Accuracy score is 81.68316831683168
# At cross fold 9 the Cross Val score is 76.36165577342048 and Accuracy score is 81.68316831683168

# %% [markdown]
# # 5) GradientBoostingClassifier

# %%
# Gradient Boosting Classifier
from sklearn.ensemble import GradientBoostingClassifier

gbk = GradientBoostingClassifier()
gbk.fit(x_train, y_train)
pred_gbk = gbk.predict(x_test)
print('Accuracy score''\n',accuracy_score(pred_gbk,y_test))
print('Confusion Matrix''\n',confusion_matrix(y_test,pred_gbk))
print('Classification Report''\n',classification_report(y_test,pred_gbk))
# Out:
# Accuracy score
#  0.8366336633663366
# Confusion Matrix
#  [[141  25]
#  [  8  28]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.95      0.85      0.90       166
#            1       0.53      0.78      0.63        36
#
#     accuracy                           0.84       202
#    macro avg       0.74      0.81      0.76       202
# weighted avg       0.87      0.84      0.85       202

# %% [markdown]
# Cross Validation

# %%
test_accuracy= accuracy_score(y_test,pred_gbk)

from sklearn.model_selection import cross_val_score
for i in range(2,10):
    cv_score=cross_val_score(gbk,x,y,cv=i,n_jobs=5)
    cv_mean=cv_score.mean()
    print(f"At cross fold {i} the Cross Val score is {cv_mean*100} and Accuracy score is {test_accuracy*100}")
# Out:
# At cross fold 2 the Cross Val score is 81.59041394335512 and Accuracy score is 83.66336633663366
# At cross fold 3 the Cross Val score is 81.69934640522877 and Accuracy score is 83.66336633663366
# At cross fold 4 the Cross Val score is 81.91807480539207 and Accuracy score is 83.66336633663366
# At cross fold 5 the Cross Val score is 83.12069375148491 and Accuracy score is 83.66336633663366
# At cross fold 6 the Cross Val score is 81.8082788671024 and Accuracy score is 83.66336633663366
# At cross fold 7 the Cross Val score is 82.89878060870429 and Accuracy score is 83.66336633663366
# At cross fold 8 the Cross Val score is 81.27002288329518 and Accuracy score is 83.66336633663366
# At cross fold 9 the Cross Val score is 82.78867102396514 and Accuracy score is 83.66336633663366

# %% [markdown]
# # 6) ExtraTreesClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier

ETC=ExtraTreesClassifier()
ETC.fit(x_train,y_train)
pred_ETC=ETC.predict(x_test)
print('Accuracy score''\n',accuracy_score(y_test,pred_ETC))
print('Confusion Matrix''\n',confusion_matrix(y_test,pred_ETC))
print('Classification Report''\n',classification_report(y_test,pred_ETC))
# Out:
# Accuracy score
#  0.806930693069307
# Confusion Matrix
#  [[154  12]
#  [ 27   9]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89       166
#            1       0.43      0.25      0.32        36
#
#     accuracy                           0.81       202
#    macro avg       0.64      0.59      0.60       202
# weighted avg       0.78      0.81      0.79       202

# %% [markdown]
# Cross Validation

# %%
test_accuracy= accuracy_score(y_test,pred_ETC)

from sklearn.model_selection import cross_val_score
for i in range(2,10):
    cv_score=cross_val_score(ETC,x,y,cv=i)
    cv_mean=cv_score.mean()
    print(f"At cross fold {i} the Cross Val score is {cv_mean*100} and Accuracy score is {test_accuracy*100}")
# Out:
# At cross fold 2 the Cross Val score is 76.47058823529412 and Accuracy score is 80.6930693069307
# At cross fold 3 the Cross Val score is 75.599128540305 and Accuracy score is 80.6930693069307
# At cross fold 4 the Cross Val score is 77.45111068919688 and Accuracy score is 80.6930693069307
# At cross fold 5 the Cross Val score is 77.56296032311714 and Accuracy score is 80.6930693069307
# At cross fold 6 the Cross Val score is 76.90631808278866 and Accuracy score is 80.6930693069307
# At cross fold 7 the Cross Val score is 76.79769340074684 and Accuracy score is 80.6930693069307
# At cross fold 8 the Cross Val score is 76.47025171624713 and Accuracy score is 80.6930693069307
# At cross fold 9 the Cross Val score is 76.90631808278866 and Accuracy score is 80.6930693069307

# %% [markdown]
# # 7)KNeighborsClassifier

# %%
from sklearn import neighbors
from sklearn.neighbors import KNeighborsClassifier

knc=KNeighborsClassifier()
knc.fit(x_train,y_train)
pred_knc=knc.predict(x_test)
print('Accuracy score''\n',accuracy_score(y_test,pred_knc))
print('Confusion Matrix''\n',confusion_matrix(y_test,pred_knc))
print('Classification Report''\n',classification_report(y_test,pred_knc))
# Out:
# Accuracy score
#  0.7871287128712872
# Confusion Matrix
#  [[153  13]
#  [ 30   6]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88       166
#            1       0.32      0.17      0.22        36
#
#     accuracy                           0.79       202
#    macro avg       0.58      0.54      0.55       202
# weighted avg       0.74      0.79      0.76       202

# %% [markdown]
# Cross Validation

# %%
test_accuracy= accuracy_score(y_test,pred_knc)

from sklearn.model_selection import cross_val_score
for i in range(2,10):
    cv_score=cross_val_score(knc,x,y,cv=i)
    cv_mean=cv_score.mean()
    print(f"At cross fold {i} the Cross Val score is {cv_mean*100} and Accuracy score is {test_accuracy*100}")
# Out:
# At cross fold 2 the Cross Val score is 72.33115468409585 and Accuracy score is 78.71287128712872
# At cross fold 3 the Cross Val score is 72.44008714596949 and Accuracy score is 78.71287128712872
# At cross fold 4 the Cross Val score is 72.8778241883425 and Accuracy score is 78.71287128712872
# At cross fold 5 the Cross Val score is 72.55405084343074 and Accuracy score is 78.71287128712872
# At cross fold 6 the Cross Val score is 73.63834422657952 and Accuracy score is 78.71287128712872
# At cross fold 7 the Cross Val score is 73.42453983675358 and Accuracy score is 78.71287128712872
# At cross fold 8 the Cross Val score is 73.09877955758964 and Accuracy score is 78.71287128712872
# At cross fold 9 the Cross Val score is 73.20261437908496 and Accuracy score is 78.71287128712872

# %% [markdown]
# ALL THE MODEL PERFORMING WELL BUT ,GRADIENT BOOSTING CLASSIFIER IS DOING BEST IN THEM, difference between accuracy score and cv score is very less

# %% [markdown]
# # Hyper Parameter Tuning for best model.

# %%
#ExtraTreesClassifier
from sklearn.model_selection import GridSearchCV

#creating the parameter list to pass in GrideSearchcv
parameters={'max_features':['auto','sqrt','log2'],
           'max_depth':[4,5,6,7,8,9,10]}

gcv=GridSearchCV(GradientBoostingClassifier(),parameters,cv=5,scoring="accuracy")
gcv.fit(x_train,y_train)
gcv.best_params_
# Out:
# {'max_depth': 5, 'max_features': 'auto'}

# %%
gcv_pred=gcv.best_estimator_.predict(x_test)#predicting with best parameters
accuracy_score(y_test,gcv_pred)#checking the final score

print('Accuracy score''\n',accuracy_score(y_test,gcv_pred))
print('Confusion Matrix''\n',confusion_matrix(y_test,gcv_pred))
print('Classification Report''\n',classification_report(y_test,gcv_pred))
# Out:
# Accuracy score
#  0.8514851485148515
# Confusion Matrix
#  [[145  21]
#  [  9  27]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.94      0.87      0.91       166
#            1       0.56      0.75      0.64        36
#
#     accuracy                           0.85       202
#    macro avg       0.75      0.81      0.77       202
# weighted avg       0.87      0.85      0.86       202

# %% [markdown]
# Thus after hyperparameter results are good for best model gradient boosting classifier

# %% [markdown]
# # COMPARING ROC AUC PLOT WITH MODELS

# %%
# Plotting for all the models used here
from sklearn import datasets 
from sklearn import metrics
from sklearn import model_selection
from sklearn.metrics import plot_roc_curve 


disp = plot_roc_curve(ETC,x_test,y_test)     # ax_=Axes with confusion matrix
plot_roc_curve(rfc, x_test, y_test, ax=disp.ax_)
plot_roc_curve(dt, x_test, y_test, ax=disp.ax_)
plot_roc_curve(lo, x_test, y_test, ax=disp.ax_)
plot_roc_curve(svc, x_test, y_test, ax=disp.ax_)
plot_roc_curve(gbk, x_test, y_test, ax=disp.ax_)
plot_roc_curve(knc, x_test, y_test, ax=disp.ax_)




plt.legend(prop={'size':11}, loc='lower right')
plt.show()

# %% [markdown]
# AUC for Bagging Classifier is highest=90% but for our best model gradient boosting AUC is also good i.e, 88%

# %% [markdown]
# # Plotting ROC AUC for best model

# %%
from sklearn.metrics import plot_roc_curve

plot_roc_curve(gcv.best_estimator_,x_test,y_test)
plt.title("ROC AUC Plot")
plt.show()

# %% [markdown]
# # Saving the best Model

# %%
# save the model to disk
import pickle

filename = 'Customer_churn.pkl'
pickle.dump(gcv.best_estimator_, open(filename, 'wb'))
# load the model from disk

loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.8514851485148515

# %% [markdown]
# # Final Prediction Submission

# %%
import numpy as np
a = np.array(y_test)
predicted = np.array(loaded_model.predict(x_test))
df = pd.DataFrame(zip(a,predicted), columns = ["Original","Predicted"])
df
