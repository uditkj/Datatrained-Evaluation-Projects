# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # BASEBALL CASE STUDY

# %% [markdown]
# Problem Statement: This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# -- Output: Number of predicted wins (W)

# %%
#IMPORT LIBRARIES
import pandas as pd
import numpy as np

import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# # UNDERSTANDING THE DATASET FOR DATA ANALYSIS

# %% [markdown]
# 2B – Double: hits on which the batter reaches second base safely without the contribution of a fielding error
#
# 3B – Triple: hits on which the batter reaches third base safely without the contribution of a fielding error
#
# AB – At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction
#
# HR – At bats per home run: at bats divided by home runs
#
# BB – Base on balls (also called a "walk"): hitter not swinging at four pitches called out of the strike zone and awarded first base.
#
# H (or HA) – Hits allowed: total hits allowed
#
# ER – Earned run: number of runs that did not occur as a result of errors or passed balls
#
# ERA – Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched
#
# SB – Stolen base: number of bases advanced by the runner while the ball is in the possession of the defense
#
# SO – Plate appearances per strikeout: number of times a batter strikes out to their plate appearance
#
# R – Runs scored: number of times a player crosses home plate
#
# RA – Run average: number of runs allowed times nine divided by innings pitched
#
# SHO – Shutout: number of complete games pitched with no runs allowed
#
# SV – Save: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings
#
# E – Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result
#
# CG – Complete game: number of games where player was the only pitcher for their team

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS (EDA)

# %%
#CHECKING THE DIMENSIONS OF DATSETS
df.shape
# Out:
# (30, 17)

# %% [markdown]
# THIS DATASET INCLUDES  30 R0WS AND 17 COLUMNS

# %%
#CHECKING THE DATATYPE FOR DATASET
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# THIS DATASET HAVE ALL THE NUMERIC VALUE . SO THERE IS NO NEED OF ENCODING

# %%
#CHECKING THE OVERVIEW OF DATASET 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.isnull()
# Out:
#         W      R     AB      H     2B     3B     HR     BB     SO     SB  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull())
plt.title("null values")
plt.show()

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# This gives the statistical information of the dataset. The summary of this dataset looks perfect since there is no negative/ invalid values present.
#
# From the above description we can observe the following things.
#
# The counts of all the columns are same, this means there are no null values present in any of the columns.
#
# In the target column we can observe the mean is bit less than median(50%), so it is skewed to the left. Since the mean is 80.96 and maximum is 100, it means that the team won more matches.
#
# In the column R(Runs) also median is more than the mean then it is skewed to left. these differences can also be seen in the columns 2B, BB, SO, RA, ER, ERA and SHO. These columns are skewed to left.
#
# The mean is more than median in the columns AB, H, HR, SV and E which means they are skewed to right.
#
# Also the mean and the median are same in the columns 3B and SB which means the data is normal or symmetrical. Also the feature CG has mean bit higher than the meadian so its almost normal.
#
# There is a huge differences in max and 75% percentile(3rd quantile).
#
# So from these observations we can conclude that the ourliers present in many of these columns.

# %% [markdown]
# # CHECKING OUTLIERS

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
z[5,1]
# Out:
# 3.5096470447193067

# %% [markdown]
# # REMOVING OUTLIERS

# %%
df1=df[(z<3).all(axis=1)]
df1
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
df1.shape
# Out:
# (29, 17)

# %%
df=df1

# %%
df.shape
# Out:
# (29, 17)

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %% [markdown]
# # CHECKING SKEWNESS

# %% [markdown]
# DATA BETWEEN -0.5 TO 0.5 IS KNOWN AS NORMAL DATA DISTRIBUTION. MEANS DATA IS NOT MUCH SKEWED. DATA OUT OF THIS RANGE IS KNOWN AS
# SKEWED DATA.

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# COLUMNS [H , CG , SV , E] HAVE LARGE SKEWED DATA. AND ALL THE REMAINING DATA IS NORMALLY DISTRIBUTED.

# %% [markdown]
# # REMOVE SKEWNESS

# %%
from sklearn.preprocessing import power_transform

df['H']=power_transform(df,method='yeo-johnson')
df['H'].skew()
# Out:
# -0.01556015493693747

# %%
df['CG']=power_transform(df,method='yeo-johnson')
df['CG'].skew()
# Out:
# -0.01556015493693747

# %%
df['SV']=power_transform(df,method='yeo-johnson')
df['SV'].skew()
# Out:
# -0.01556015493693747

# %%
df['E']=power_transform(df,method='yeo-johnson')
df['E'].skew()
# Out:
# -0.01556015493693747

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H     -0.015560
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.015560
# SHO    0.526943
# SV    -0.015560
# E     -0.015560
# dtype: float64

# %% [markdown]
# # CHECKING THE CORRELATION

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.390451 -0.085780  0.012077  0.384886 -0.206737  0.245697
# R    0.390451  1.000000  0.438022 -0.270512  0.469293  0.134204  0.586894
# AB  -0.085780  0.438022  1.000000  0.081609  0.490752  0.445604 -0.064653
# H    0.012077 -0.270512  0.081609  1.000000 -0.001703  0.127336 -0.327934
# 2B   0.384886  0.469293  0.490752 -0.001703  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.134204  0.445604  0.127336  0.342419  1.000000 -0.369299
# HR   0.245697  0.586894 -0.064653 -0.327934 -0.098695 -0.369299  1.000000
# BB   0.447513  0.258450 -0.137850 -0.038266  0.211243 -0.404852  0.336814
# SO   0.156469  0.081158 -0.111243 -0.021828 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.075323  0.373674  0.229394  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.013858  0.315499 -0.010266 -0.215196  0.312750 -0.092586
# ER  -0.815308  0.007727  0.309146 -0.040422 -0.224993  0.333731 -0.062094
# ...

# %%
plt.figure(figsize=(22,16))
sns.heatmap(df.corr(),annot=True,cmap="Blues")
# Out:
# <AxesSubplot:>

# %% [markdown]
# (ER AND ERA HAVE) HIGH COLLINEAR WITH EACH OTHER. AND (SV AND E HAVE ALSO HIGH CORRELATED WITH EACH OTHER.)

# %% [raw]
#  WE  CAN DROP ONE COLUMN FROM ERA AND ER. BUT IT LEADS TO LOSS OUR INFORMATION. AND OUR COLUMN IS NOT TO MUCH THAT WE USE PCA.

# %% [markdown]
# # DATA VISUALIZATION

# %%
fig, axs = plt.subplots(3, 2, figsize=(18, 14))

sns.histplot(data=df, x="R", kde=True, ax=axs[0, 0], color='green')
sns.histplot(data=df, x="AB", kde=True, ax=axs[0, 1], color='skyblue')
sns.histplot(data=df, x="H", kde=True, ax=axs[1, 0], color='orange')
sns.histplot(data=df, x="2B", kde=True, ax=axs[1, 1], color='red')
sns.histplot(data=df, x="3B", kde=True, ax=axs[2, 0], color='black')
sns.histplot(data=df, x="HR", kde=True, ax=axs[2, 1], color='yellow')
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Count'>

# %% [markdown]
# RUNS(R),HITS(H) AND ATBATS PER HOME RUN(HR) ARE HAVING A LITTLE SKEWNESS PRESENT
#
# REST ALL SEEM TO BE NORMALLY DISTRIBUTED

# %%
fig, axs = plt.subplots(3, 2, figsize=(18, 14))


sns.histplot(data=df, x="BB", kde=True, ax=axs[0, 0], color='green')
sns.histplot(data=df, x="SO", kde=True, ax=axs[0, 1], color='skyblue')
sns.histplot(data=df, x="SB", kde=True, ax=axs[1, 0], color='orange')
sns.histplot(data=df, x="RA", kde=True, ax=axs[1, 1], color='red')
sns.histplot(data=df, x="ER", kde=True, ax=axs[2, 0], color='black')
sns.histplot(data=df, x="ERA", kde=True, ax=axs[2, 1], color='yellow')
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Count'>

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=df,x='W',y='R')
# Out:
# <AxesSubplot:xlabel='W', ylabel='R'>

# %% [markdown]
# IT IS OBVIOUS MOSTLY MORE RUNS WILL LEAD TO WINNINGS

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=df,x='3B',y='SB')
# Out:
# <AxesSubplot:xlabel='3B', ylabel='SB'>

# %% [markdown]
# NUMBER OF STOLEN BASSES ARE HIGH AS THIRD BASE RUN INCREASES

# %%
plt.figure(figsize=(10,8))
sns.lineplot(data=df,x='ER',y='ERA')
# Out:
# <AxesSubplot:xlabel='ER', ylabel='ERA'>

# %% [markdown]
# ER AND ERA ARE ALMOST SIMILAR DATAS
#
# AS ER INCREASES ERA ALSO INCREASES

# %%
plt.figure(figsize=(22,7))
df.corr()['W'].sort_values(ascending=False).plot(kind='bar',color='c')
plt.xlabel('feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# E,SB,3B,ER,ERA,RA,AB ARE NEGATIVELY CORRELATED

# %%
sns.set(style="darkgrid")
df.plot(kind='box',subplots=True,layout=(6,3),figsize=(10,15),color = 'green')
plt.tight_layout()

# %% [markdown]
# # FEATURE AND LABELLING OF DATAFRAME

# %%
x=df.iloc[:,1:-1]
y=df.iloc[:,0]

# %%
x.shape
# Out:
# (29, 15)

# %%
y.shape
# Out:
# (29,)

# %% [markdown]
# # SCALING OF DATA

# %%
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
x=sd.fit_transform(x)
x
# Out:
# array([[ 0.95939835,  0.83008422,  0.98569193,  1.55653766,  1.01084549,
#         -0.76586314, -1.53635899, -2.72762331,  0.9059529 , -0.66451353,
#         -0.51114812, -0.51138828,  0.98569193, -0.81326172,  0.98569193],
#        [ 0.33114717, -0.70283074, -0.97273429,  0.20117132,  1.20891656,
#         -0.18138864, -0.49502051,  0.12189552, -0.58531515,  0.15463823,
#          0.23216082,  0.23895226, -0.97273429,  0.15929869, -0.97273429],
#        [-0.27466646, -1.10025314, -1.31520654,  1.73332457, -0.2766165 ,
#         -0.69710144,  1.25294051, -0.9258657 ,  0.11645805, -0.67839746,
#         -0.75415297, -0.64380131, -1.31520654, -0.32698152, -1.31520654],
#        [-1.32923093,  0.23395062, -0.72485257, -0.8006212 , -0.47468758,
#         -0.8690057 , -1.14585706, -0.20124579, -0.6730368 ,  0.16852216,
#          0.08921679,  0.04033271, -0.72485257, -0.57012162, -0.72485257],
#        [ 0.17408438,  1.25589393, -0.36372238,  0.90831897,  1.70409425,
# ...

# %% [markdown]
# # SPLITTING DATAFRAME

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=66)

# %% [markdown]
# # MODEL SELECTION

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
lrpred=lr.predict(x_test)

print("score:",lr.score(x_train,y_train))
print("r2 score:",r2_score(y_test,lrpred))

print("Mean Absolute Error:", mean_absolute_error(y_test,lrpred))
print("Mean Squared Error:", mean_squared_error(y_test,lrpred))
# Out:
# score: 0.97257404738074
# r2 score: 0.4836283474235742
# Mean Absolute Error: 5.546706273602579
# Mean Squared Error: 37.096139521090436

# %%
from sklearn.tree import DecisionTreeRegressor

dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
dtrpred=dtr.predict(x_test)

print("score:",lr.score(x_train,y_train))
print("r2 score:",r2_score(y_test,dtrpred))

print("Mean Absolute Error:", mean_absolute_error(y_test,dtrpred))
print("Mean Squared Error:", mean_squared_error(y_test,dtrpred))
# Out:
# score: 0.97257404738074
# r2 score: 0.4056236080178175
# Mean Absolute Error: 4.3
# Mean Squared Error: 42.7

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
rfpred=rf.predict(x_test)

print('Score: ',rf.score(x_train,y_train))
print('r2 score: ', r2_score(y_test,rfpred))


print('Mean absolute error:', mean_absolute_error(y_test,rfpred))
print('Mean squared error:', mean_squared_error(y_test,rfpred))
# Out:
# Score:  0.9412327904247829
# r2 score:  0.42371255567928734
# Mean absolute error: 4.795
# Mean squared error: 41.400490000000005

# %%
from sklearn.svm import SVR
svr= SVR()
svr.fit(x_train,y_train)
preds= svr.predict(x_test)
print('Score: ',svr.score(x_train,y_train))
print('r2 score: ', r2_score(y_test,preds))


print('Mean absolute error:', mean_absolute_error(y_test,preds))
print('Mean squared error:', mean_squared_error(y_test,preds))
# Out:
# Score:  0.22588048441249042
# r2 score:  0.10909803666610118
# Mean absolute error: 6.910507546196017
# Mean squared error: 64.0023970459073

# %%
# Regularization

from sklearn.linear_model import Lasso

ls= Lasso()
ls.fit(x_train,y_train)
predls= ls.predict(x_test)
print('Score: ',ls.score(x_train,y_train))
print('r2 score: ', r2_score(y_test,predls))


print('Mean absolute error:', mean_absolute_error(y_test,predls))
print('Mean squared error:', mean_squared_error(y_test,predls))
# Out:
# Score:  0.8556775605180269
# r2 score:  0.5917934413340432
# Mean absolute error: 4.557333137102317
# Mean squared error: 29.32555917456234

# %%
# Regularization

from sklearn.linear_model import Ridge

rd= Ridge()
rd.fit(x_train,y_train)
rdpred= rd.predict(x_test)
print('Score: ',rd.score(x_train,y_train))
print('r2 score: ', r2_score(y_test,rdpred))


print('Mean absolute error:', mean_absolute_error(y_test,rdpred))
print('Mean squared error:', mean_squared_error(y_test,rdpred))
# Out:
# Score:  0.9003037496828465
# r2 score:  0.500708754457996
# Mean absolute error: 5.362419980979537
# Mean squared error: 35.869083079737564

# %% [markdown]
# # CROSS VALIDATION

# %%
from sklearn.model_selection import cross_val_score

# %%
#FOR LINEAR REGRESSOR
test_accuracy=r2_score(lrpred,y_test)
for i in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=i)
    cv_mean=cv_score.mean()
    print('At cross fold',i, 'the Cross Val score is',cv_mean*100,'and Accuracy score is', test_accuracy*100)
# Out:
# At cross fold 2 the Cross Val score is -1400.3687166374164 and Accuracy score is 66.42763091296166
# At cross fold 3 the Cross Val score is 48.63630056835461 and Accuracy score is 66.42763091296166
# At cross fold 4 the Cross Val score is 56.61877697316478 and Accuracy score is 66.42763091296166
# At cross fold 5 the Cross Val score is 46.56534220637852 and Accuracy score is 66.42763091296166
# At cross fold 6 the Cross Val score is 62.834021840341045 and Accuracy score is 66.42763091296166
# At cross fold 7 the Cross Val score is 55.650928717983724 and Accuracy score is 66.42763091296166
# At cross fold 8 the Cross Val score is 56.48556201785433 and Accuracy score is 66.42763091296166
# At cross fold 9 the Cross Val score is -1179.3672891079723 and Accuracy score is 66.42763091296166

# %%
#FOR DTR
test_accuracy=r2_score(y_test,dtrpred)
for i in range(2,10):
    cv_score=cross_val_score(dtr,x,y,cv=i)
    cv_mean=cv_score.mean()
    print('At cross fold',i, 'the Cross Val score is',cv_mean*100,'and Accuracy score is', test_accuracy*100)
# Out:
# At cross fold 2 the Cross Val score is -58.218664277411406 and Accuracy score is 40.56236080178175
# At cross fold 3 the Cross Val score is 8.08227696489447 and Accuracy score is 40.56236080178175
# At cross fold 4 the Cross Val score is 47.55815851635806 and Accuracy score is 40.56236080178175
# At cross fold 5 the Cross Val score is -124.1208874493404 and Accuracy score is 40.56236080178175
# At cross fold 6 the Cross Val score is -36.816849143160304 and Accuracy score is 40.56236080178175
# At cross fold 7 the Cross Val score is -79.93212580487 and Accuracy score is 40.56236080178175
# At cross fold 8 the Cross Val score is -72.3613991088477 and Accuracy score is 40.56236080178175
# At cross fold 9 the Cross Val score is -122.12056071089663 and Accuracy score is 40.56236080178175

# %%
#for svr
test_accuracy=r2_score(y_test,preds)
for i in range(2,10):
    cv_score=cross_val_score(svr,x,y,cv=i)
    cv_mean=cv_score.mean()
    print('At cross fold',i, 'the Cross Val score is',cv_mean*100,'and Accuracy score is', test_accuracy*100)
# Out:
# At cross fold 2 the Cross Val score is -21.502733368125206 and Accuracy score is 10.909803666610118
# At cross fold 3 the Cross Val score is -25.46592724841968 and Accuracy score is 10.909803666610118
# At cross fold 4 the Cross Val score is -7.368574912568504 and Accuracy score is 10.909803666610118
# At cross fold 5 the Cross Val score is -34.25797731944588 and Accuracy score is 10.909803666610118
# At cross fold 6 the Cross Val score is -17.261973241873388 and Accuracy score is 10.909803666610118
# At cross fold 7 the Cross Val score is -26.477260300036626 and Accuracy score is 10.909803666610118
# At cross fold 8 the Cross Val score is -51.26874917762987 and Accuracy score is 10.909803666610118
# At cross fold 9 the Cross Val score is -2604.514585106248 and Accuracy score is 10.909803666610118

# %%
#for Random Forest Regressor
test_accuracy=r2_score(y_test,rfpred)
for i in range(2,10):
    cv_score=cross_val_score(rf,x,y,cv=i)
    cv_mean=cv_score.mean()
    print('At cross fold',i, 'the Cross Val score is',cv_mean*100,'and Accuracy score is', test_accuracy*100)
# Out:
# At cross fold 2 the Cross Val score is -6.0984105573970435 and Accuracy score is 42.371255567928735
# At cross fold 3 the Cross Val score is 15.06245222361634 and Accuracy score is 42.371255567928735
# At cross fold 4 the Cross Val score is 56.97974534849638 and Accuracy score is 42.371255567928735
# At cross fold 5 the Cross Val score is -10.839881908633577 and Accuracy score is 42.371255567928735
# At cross fold 6 the Cross Val score is 13.252243200714235 and Accuracy score is 42.371255567928735
# At cross fold 7 the Cross Val score is 21.596181698019095 and Accuracy score is 42.371255567928735
# At cross fold 8 the Cross Val score is -12.895616318874541 and Accuracy score is 42.371255567928735
# At cross fold 9 the Cross Val score is -1980.4960296788333 and Accuracy score is 42.371255567928735

# %%
#for lasso
test_accuracy=r2_score(y_test,predls)
for i in range(2,10):
    cv_score=cross_val_score(ls,x,y,cv=i)
    cv_mean=cv_score.mean()
    print('At cross fold',i, 'the Cross Val score is',cv_mean*100,'and Accuracy score is', test_accuracy*100)
# Out:
# At cross fold 2 the Cross Val score is 47.90805143404021 and Accuracy score is 59.17934413340432
# At cross fold 3 the Cross Val score is 37.89604798263159 and Accuracy score is 59.17934413340432
# At cross fold 4 the Cross Val score is 68.5656207045241 and Accuracy score is 59.17934413340432
# At cross fold 5 the Cross Val score is 38.805515169699106 and Accuracy score is 59.17934413340432
# At cross fold 6 the Cross Val score is 52.130324169321675 and Accuracy score is 59.17934413340432
# At cross fold 7 the Cross Val score is 52.163419863660046 and Accuracy score is 59.17934413340432
# At cross fold 8 the Cross Val score is 44.74849187982127 and Accuracy score is 59.17934413340432
# At cross fold 9 the Cross Val score is -688.2700930306609 and Accuracy score is 59.17934413340432

# %%
#RIDGE REGRESSOR
test_accuracy= r2_score(y_test,rdpred)

from sklearn.model_selection import cross_val_score
for i in range(2,10):
    cv_score=cross_val_score(rd,x,y,cv=i)
    cv_mean=cv_score.mean()
    print('At cross fold',i, 'the Cross Val score is',cv_mean*100,'and Accuracy score is', test_accuracy*100)
# Out:
# At cross fold 2 the Cross Val score is -1.4535974043380195 and Accuracy score is 50.0708754457996
# At cross fold 3 the Cross Val score is 28.644001194326968 and Accuracy score is 50.0708754457996
# At cross fold 4 the Cross Val score is 56.694504744778705 and Accuracy score is 50.0708754457996
# At cross fold 5 the Cross Val score is 33.07452954443038 and Accuracy score is 50.0708754457996
# At cross fold 6 the Cross Val score is 41.216554799699416 and Accuracy score is 50.0708754457996
# At cross fold 7 the Cross Val score is 41.39691954031189 and Accuracy score is 50.0708754457996
# At cross fold 8 the Cross Val score is 32.828291569577104 and Accuracy score is 50.0708754457996
# At cross fold 9 the Cross Val score is -1417.4192178369353 and Accuracy score is 50.0708754457996

# %% [markdown]
# # HYPER PARAMETER TUNNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={"alpha":[0.0001,.001,.01,1]}
gd=GridSearchCV(estimator=ls,param_grid=param_grid,cv=4)
gd.fit(x,y)
best_param=gd.best_params_
print(best_param)
best_result=gd.best_score_
print(best_result*100)
# Out:
# {'alpha': 1}
# 68.5656207045241

# %% [markdown]
# # NOW USING ALL THE PAREMETER TAKE OUT THE BEST MODEL PERFORMANCE

# %%
ls2= Lasso(alpha=1)
ls2.fit(x_train,y_train)
predls2= ls2.predict(x_test)
print('Score: ',ls2.score(x_train,y_train))
print('r2 score: ', r2_score(y_test,predls2))
# Out:
# Score:  0.8556775605180269
# r2 score:  0.5917934413340432

# %%
test_accuracy= r2_score(y_test,predls2)

from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(ls,x,y,cv=4)
cv_mean=cv_score.mean()
print(f"At cross fold 4 the Cross Val score is {cv_mean*100} and Accuracy score is {test_accuracy*100}")
# Out:
# At cross fold 4 the Cross Val score is 68.5656207045241 and Accuracy score is 59.17934413340432

# %%
plt.figure(figsize=(8,7))
plt.scatter(x=y_test, y= predls2, color='r')
plt.plot(y_test,y_test, color='b')
plt.xlabel('Actual sale', fontsize= 14 )
plt.ylabel('predicted sale', fontsize= 18)
plt.show()

# %% [markdown]
# # SAVING OUR BEST MODEL

# %%
import pickle

# %%
filename="baseball_win.pkl"
pickle.dump(ls2,open(filename,"wb"))

# %%
import numpy as np
a=np.array(y_test)
predicted= np.array(ls2.predict(x_test))
df_check= pd.DataFrame({'original':a, 'predicted':predicted}, index= range(len(a)))
df_check
# Out:
#    original  predicted
# 0      78.0  75.956376
# 1      83.0  78.234442
# 2      88.0  78.314055
# 3      87.0  82.527330
# 4      64.0  72.527588
# 5      74.0  68.009534
# 6      76.0  76.000992
# 7      76.0  74.582134
# 8      92.0  89.141839
# 9      68.0  73.810462
